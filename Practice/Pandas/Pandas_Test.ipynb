# %%
import pandas as pd
df = pd.read_csv("dali.csv")
#print(df)
#id = df[["city"]]=="臺中市"
#print(id)
o3_hight = df[df["o3"]>10 ]
#print(o3_hight)
#print(df[id&o3_hight])
#df[id&o3_hight]
# Out:
# None

# %%
desc = df.sort_values(["o3"],ascending=False,inplace=True)
print(desc)
#desc[desc["station"]]=="大里"
# Out:
# None

# %%
o3_low30 = df[df["o3"]<30]
#print(o3_low30 )
#print( o3+low30 | o3_hight)
for index , row in df.iterrows():
    id = row['id']
    city=row['city']
    o3=row['o3']
    if(o3>15 and o3<20 ):
        
        print ( str(id) + "-" + city + " : " + str(o3))
# Out:
# 14502-臺中市 : 19.0
# 11211-臺中市 : 19.0
# 10155-臺中市 : 19.0
# 13330-臺中市 : 19.0
# 16705-臺中市 : 19.0
# 6333-臺中市 : 19.0
# 14401-臺中市 : 19.0
# 13313-臺中市 : 19.0
# 17987-臺中市 : 19.0
# 14402-臺中市 : 19.0
# 10156-臺中市 : 19.0
# 17985-臺中市 : 19.0
# 4553-臺中市 : 19.0
# 5647-臺中市 : 19.0
# 16798-臺中市 : 19.0
# 9729-臺中市 : 19.0
# 8214-臺中市 : 19.0
# 6937-臺中市 : 19.0
# 5887-臺中市 : 19.0
# 17992-臺中市 : 19.0
# 415-臺中市 : 19.0
# 8675-臺中市 : 19.0
# 8850-臺中市 : 19.0
# 4392-臺中市 : 19.0
# 2793-臺中市 : 19.0
# 16690-臺中市 : 19.0
# 4897-臺中市 : 19.0
# 18562-臺中市 : 19.0
# 10254-臺中市 : 19.0
# 16666-臺中市 : 19.0
# 1028-臺中市 : 19.0
# 19415-臺中市 : 19.0
# 13272-臺中市 : 19.0
# 9120-臺中市 : 19.0
# 9121-臺中市 : 19.0
# 4220-臺中市 : 19.0
# 403-臺中市 : 19.0
# 5591-臺中市 : 19.0
# 1231-臺中市 : 19.0
# 16629-臺中市 : 19.0
# 6940-臺中市 : 19.0
# 3309-臺中市 : 19.0
# 1222-臺中市 : 19.0
# 13305-臺中市 : 19.0
# 17361-臺中市 : 19.0
# 10251-臺中市 : 19.0
# 10248-臺中市 : 19.0
# 305-臺中市 : 19.0
# 18305-臺中市 : 19.0
# 1545-臺中市 : 19.0
# 3885-臺中市 : 19.0
# 17181-臺中市 : 19.0
# 2326-臺中市 : 19.0
# 7098-臺中市 : 19.0
# ...

# %%
o3levelInRange = []
while df['o3']>10:
    while df['o3']<30:
        o3levelInRange.append(df['o3'])
print(o3levelInRange)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-a61972717945> in <module>
#       1 o3levelInRange = []
# ----> 2 while df['o3']>10:
#       3     while df['o3']<30:
#       4         o3levelInRange.append(df['o3'])
#       5 print(o3levelInRange)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
